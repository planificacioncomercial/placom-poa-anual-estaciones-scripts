# %%
# %pip install openpyxl
# %pip install pandas

# %%
from openpyxl import Workbook, load_workbook
from win32com import client
import shutil
import pandas as pd
import os
from pywintypes import com_error
import shutil
from pathlib import Path
from openpyxl import load_workbook

# %%
def write_block(df, eds, worksheet, row_start, col_start=6, row_slice=slice(None)):
    """Escribe un bloque de datos de base_poa en la hoja Excel."""
    df_filtered = df.loc[df.CodEs == eds].iloc[row_slice, 4:].values

    for row_offset, row in enumerate(df_filtered):
        for col_offset, valor in enumerate(row):
            worksheet.cell(row=row_start + row_offset, column=col_start + col_offset, value=valor)


def eds_file(base_poa, base_app_copec, jz, eds, dir_molde: Path, dir_destino: Path):
    """Genera archivo POA para concesionarios con datos de base_poa y base_app_copec."""

    # Copiar molde (más rápido que copy2 si no necesitas metadata exacta como permisos/fechas)
    shutil.copy(dir_molde, dir_destino)

    workbook = load_workbook(dir_destino)
    
    # Seleccionar hoja "Plan Teórico"
    if "Plan Teórico" in workbook.sheetnames:
        workbook.active = workbook.sheetnames.index("Plan Teórico")
        
    worksheet = workbook.active

    # Bloques de escritura predefinidos
    bloques = [
        (slice(0, 7), 17),
        (slice(7, 13), 25),
        (slice(13, 16), 32),
        (slice(16, None), 36),
    ]

    # Escritura en bloque (más eficiente que cell-by-cell dentro de write_block)
    for row_slice, row_start in bloques:
        write_block(base_poa, eds, worksheet, row_start, row_slice=row_slice)

    # Procesar base_app_copec solo si tiene datos
    df_app = base_app_copec.loc[base_app_copec.CodEs == eds]
    if not df_app.empty:
        row_start, col_start = 41, 6
        valores = df_app.iloc[0, 1:].replace({'-': 0}).round(3).to_numpy()
        for col_offset, valor in enumerate(valores, start=0):
            worksheet.cell(row=row_start, column=col_start + col_offset, value=valor)

    # Proteger hojas solo si es necesario (evita overhead si ya están protegidas)
    if not worksheet.protection.sheet:
        worksheet.protection.sheet = True
        
    if "Plan Definitivo" in workbook.sheetnames:
        plan_def = workbook["Plan Definitivo"]
        if not plan_def.protection.sheet:
            plan_def.protection.sheet = True

    # Guardar (usa overwrite para no duplicar handles en disco)
    workbook.save(dir_destino)
    

def eds_file_old(base_poa, base_app_copec, jz, eds, dir_molde: Path, dir_destino: Path):
    """Genera archivo POA para concesionarios con datos de base_poa y base_app_copec."""

    # Copiar molde
    shutil.copy2(dir_molde, dir_destino)

    workbook = load_workbook(dir_destino)
    worksheet = workbook.active

    # Escribir bloques definidos
    bloques = [
        (slice(0, 7), 17),   # filas 0–6 → fila Excel 17
        (slice(7, 13), 25),  # filas 7–12 → fila Excel 25
        (slice(13, 16), 32), # filas 13–15 → fila Excel 32
        (slice(16, None), 36) # desde fila 16 → fila Excel 36
    ]

    for row_slice, row_start in bloques:
        write_block(base_poa, eds, worksheet, row_start, row_slice=row_slice)

    # Cargar base_app_copec si tiene datos
    df_app = base_app_copec.loc[base_app_copec.CodEs == eds]
    if not df_app.empty:
        row_start, col_start = 41, 6
        for col_offset, valor in enumerate(df_app.iloc[0, 1:].replace({'-': 0}).values):
            worksheet.cell(row=row_start, column=col_start + col_offset, value=round(valor, 3))

    # Proteger hojas
    worksheet.protection.sheet = True
    workbook["Plan Definitivo"].protection.sheet = True

    # Guardar
    workbook.save(dir_destino)


def eds_file_final(base_poa, jz, eds, dir_molde: Path, dir_destino: Path):
    """Versión final de archivo POA (sin base_app_copec)."""

    shutil.copy2(dir_molde, dir_destino)

    workbook = load_workbook(dir_destino)
    worksheet = workbook.active

    bloques = [
        (slice(0, 7), 17),
        (slice(7, 13), 25),
        (slice(13, 16), 32),
        (slice(16, None), 36)
    ]

    for row_slice, row_start in bloques:
        write_block(base_poa, eds, worksheet, row_start, row_slice=row_slice)

    if "Plan Definitivo" in workbook.sheetnames:
        plan_def = workbook["Plan Definitivo"]
        if not plan_def.protection.sheet:
            plan_def.protection.sheet = True
            
    workbook.save(dir_destino)


# ---- Diccionario global para sum_prop ----
DICC_PROP = {
    ('DSL', 'Cupón Electrónico'): 0.00004724,
    ('DSL', 'FF.AA'): 0.00000137,
    ('DSL', 'Cuenta Empresa'): 0.00001175,
    ('DSL', 'TAE'): 0.0000678,
    ('DSL', 'TCT'): 0.00014023,
    ('DSL', 'Venta Propia - Camión de Reparto'): 0.00000634,
    ('DSL', 'Venta Propia - Isla'): 0.00024819,
    ('GAS', 'Cupón Electrónico'): 0.00000837,
    ('GAS', 'FF.AA'): 0.0000031,
    ('GAS', 'G93 - VP'): 0.00029,
    ('GAS', 'G95 - VP'): 0.0000944,
    ('GAS', 'G97 - VP'): 0.00006226,
    ('GAS', 'Cuenta Empresa'): 0.00000345,
    ('GASES', 'GLP'): 0.00000105,
    ('GASES', 'GNC'): 0.00000115,
    ('KER', 'Cuenta Empresa'): 0.00000002,
    ('KER', 'Venta Propia - Camión de Reparto'): 0.0000004,
    ('KER', 'Venta Propia - Isla'): 0.00001291
}


def sum_prop(prod, form_com):
    """Devuelve el valor de proporción según producto y forma de comercialización."""
    return DICC_PROP.get((prod, form_com), 0)

# %% [markdown]
# ## Archivos Iniciales en base al año en curso

# %%
# ---- Directorios base ----
base_dir = Path(r"G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial")

dir_base = base_dir / "Carga Inicial" / "Archivos por Zona Respaldo"
dir_maestro_eds = base_dir / "Carga Inicial" / "Maestro EDS.xlsx"
# dir_archivo_base = base_dir / "Carga Inicial" / "(Paso-1) ArchivosSinProyMacro" / "base_poa_vol_inicial - python.xlsx"
# dir_archivo_app_copec = base_dir / "Carga Inicial" / "(Paso-1) ArchivosSinProyMacro" / "base_poa_app_copec.xlsx"
# dir_archivo_base = base_dir / "Carga Inicial" / "(Paso-3) Mercado" / "base_poa_vol_inicial - python.xlsx"
# dir_archivo_base = base_dir / "Carga Inicial" / "(Paso-3) Mercado" /  "base_poa_vol_inicial - python - Carga Inicial_SinAfectaciones.xlsx"
dir_archivo_base = Path(r"G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026") / "VolumenFinalValores - python.xlsx"
dir_archivo_app_copec = base_dir / "Carga Inicial" / "(Paso-3) Mercado" / "base_poa_app_copec.xlsx"

# ---- Configuración ----
zonas = [209, 210, 211, 212, 213, 214, 215, 216, 217, 
218, 219, 220, 221, 230, 231, 232, 233, 234, 
235, 240, 241, 242, 243, 244, 245, 246, 247, 
248, 249]  # , 211, ..., 248

# zonas = [214]

# ---- Carga maestro ----
maestro_eds = pd.read_excel(dir_maestro_eds, usecols=[0, 5], sheet_name="Consolidado VF")
estacionales = pd.read_excel(dir_maestro_eds, usecols=[0, 12], names=["CodEs", "JZ"], sheet_name="Estacionales")

# Concatenar ambos
maestro_eds = pd.concat([maestro_eds, estacionales], ignore_index=True)
maestro_eds["CodEs"] = maestro_eds["CodEs"].fillna(0).astype(int)
maestro_eds["JZ"] = maestro_eds["JZ"].fillna(0).astype(int)

# ---- Bases de datos ----
# base_poa = pd.read_excel(dir_archivo_base, skiprows=1, sheet_name="Carga Inicial")
base_poa = pd.read_excel(dir_archivo_base, skiprows=1, sheet_name="VolumenFinal")
print(base_poa.columns.tolist())
base_app_copec = pd.read_excel(dir_archivo_app_copec)
# base_poa["CodEs"] = base_poa["CodEs"].fillna(0).astype(int)
base_poa["CodEs"] = base_poa["Estación "].fillna(0).astype(int)
base_poa.drop(columns=["Estación "], inplace=True)

print(base_poa.head())

# ---- Detalles forma comercial ----
details_form_com = [
    ("DSL", "Cupón Electrónico"),
    ("DSL", "FF.AA"),
    ("DSL", "Cuenta Empresa"),
    ("DSL", "TAE"),
    ("DSL", "TCT"),
    ("DSL", "Venta Propia - Camión de Reparto"),
    ("DSL", "Venta Propia - Isla"),
    ("GAS", "Cupón Electrónico"),
    ("GAS", "FF.AA"),
    ("GAS", "G93 - VP"),
    ("GAS", "G95 - VP"),
    ("GAS", "G97 - VP"),
    ("GAS", "Cuenta Empresa"),
    ("GASES", "GLP"),
    ("GASES", "GNC"),
    ("KER", "Cuenta Empresa"),
    ("KER", "Venta Propia - Camión de Reparto"),
    ("KER", "Venta Propia - Isla"),
]

# ---- Columnas proyectadas ----
years = [2024, 2025, 2026]
months = [f"{m:02}" for m in range(1, 13)]
cols_proy = [f"{y}-{m:02}" for y in years for m in months]

# ---- Asegurar que las columnas proyectadas sean numéricas ----
base_poa[cols_proy] = base_poa[cols_proy].apply(pd.to_numeric, errors='coerce')

# ---- Aplicar sum_prop por cada combinación ----
for prod, form_com in details_form_com:
    mask = (base_poa["Producto"] == prod) & (base_poa["Forma Comercialización"] == form_com)
    incremento = sum_prop(prod, form_com)
    print(f"Producto: {prod}, Forma Comercialización: {form_com}, Incremento: {incremento:.8f}")
    base_poa.loc[mask, cols_proy] = base_poa.loc[mask, cols_proy].add(incremento)

base_poa
# Out:
# ['Estación ', 'Producto', 'Forma Comercialización', 'Estado', '2024-01', '2024-02', '2024-03', '2024-04', '2024-05', '2024-06', '2024-07', '2024-08', '2024-09', '2024-10', '2024-11', '2024-12', '2025-01', '2025-02', '2025-03', '2025-04', '2025-05', '2025-06', '2025-07', '2025-08', '2025-09', '2025-10', '2025-11', '2025-12', '2026-01', '2026-02', '2026-03', '2026-04', '2026-05', '2026-06', '2026-07', '2026-08', '2026-09', '2026-10', '2026-11', '2026-12']
#   Producto Forma Comercialización  Estado  2024-01  2024-02  2024-03  2024-04  \
# 0      DSL         Cuenta Empresa  Normal   17.093   17.840   15.675   16.847
# 1      DSL      Cupón Electrónico  Normal   65.066   57.079   61.543   66.675
# 2      DSL                  FF.AA  Normal    1.388    0.471    1.341    1.425
# 3      DSL                    TAE  Normal    0.000    0.000    0.000    0.000
# 4      DSL                    TCT  Normal    0.000    0.000    0.000    0.000
#
#    2024-05  2024-06  2024-07  ...    2026-04    2026-05    2026-06    2026-07  \
# 0   20.975   18.218   23.215  ...  30.696490  28.798842  31.295954  25.244045
# 1   62.909   58.689   65.320  ...  63.344421  61.606771  62.925819  59.229536
# 2    0.781    1.032    0.316  ...   0.664139   0.866439   1.310514   1.196392
# 3    0.000    0.000    0.000  ...   0.000000   0.000000   0.000000   0.000000
# 4    0.000    0.000    0.000  ...   0.000000   0.000000   0.000000   0.000000
#
#      2026-08    2026-09    2026-10    2026-11    2026-12  CodEs
# 0  39.074601  31.989894  32.755733  33.596222  33.496883  10004
# 1  58.084227  57.581120  60.439003  62.824109  59.110899  10004
# 2   0.828045   0.634540   0.967160   1.123311   0.935929  10004
# 3   0.000000   0.000000   0.000000   0.000000   0.000000  10004
# 4   0.000000   0.000000   0.000000   0.000000   0.000000  10004
#
# [5 rows x 40 columns]
# Producto: DSL, Forma Comercialización: Cupón Electrónico, Incremento: 0.00004724
# Producto: DSL, Forma Comercialización: FF.AA, Incremento: 0.00000137
# Producto: DSL, Forma Comercialización: Cuenta Empresa, Incremento: 0.00001175
# Producto: DSL, Forma Comercialización: TAE, Incremento: 0.00006780
# Producto: DSL, Forma Comercialización: TCT, Incremento: 0.00014023
# Producto: DSL, Forma Comercialización: Venta Propia - Camión de Reparto, Incremento: 0.00000634
# Producto: DSL, Forma Comercialización: Venta Propia - Isla, Incremento: 0.00024819
# Producto: GAS, Forma Comercialización: Cupón Electrónico, Incremento: 0.00000837
# Producto: GAS, Forma Comercialización: FF.AA, Incremento: 0.00000310
# Producto: GAS, Forma Comercialización: G93 - VP, Incremento: 0.00029000
# Producto: GAS, Forma Comercialización: G95 - VP, Incremento: 0.00009440
# Producto: GAS, Forma Comercialización: G97 - VP, Incremento: 0.00006226
# Producto: GAS, Forma Comercialización: Cuenta Empresa, Incremento: 0.00000345
# Producto: GASES, Forma Comercialización: GLP, Incremento: 0.00000105
# Producto: GASES, Forma Comercialización: GNC, Incremento: 0.00000115
# Producto: KER, Forma Comercialización: Cuenta Empresa, Incremento: 0.00000002
# Producto: KER, Forma Comercialización: Venta Propia - Camión de Reparto, Incremento: 0.00000040
# Producto: KER, Forma Comercialización: Venta Propia - Isla, Incremento: 0.00001291
#       Producto            Forma Comercialización  Estado       2024-01  \
# 0          DSL                    Cuenta Empresa  Normal  1.709301e+01
# 1          DSL                 Cupón Electrónico  Normal  6.506605e+01
# 2          DSL                             FF.AA  Normal  1.388001e+00
# 3          DSL                               TAE  Normal  6.780000e-05
# 4          DSL                               TCT  Normal  1.402300e-04
# ...        ...                               ...     ...           ...
# 12937    GASES                               GLP  Normal  1.413300e+01
# 12938    GASES                               GNC  Normal  1.150000e-06
# 12939      KER                    Cuenta Empresa  Normal  2.000000e-08
# 12940      KER  Venta Propia - Camión de reparto  Normal  0.000000e+00
# 12941      KER               Venta Propia - Isla  Normal  1.291000e-05
#
#             2024-02       2024-03       2024-04    2024-05       2024-06  \
# 0      1.784001e+01  1.567501e+01  1.684701e+01  20.975012  1.821801e+01
# 1      5.707905e+01  6.154305e+01  6.667505e+01  62.909047  5.868905e+01
# 2      4.710014e-01  1.341001e+00  1.425001e+00   0.781001  1.032001e+00
# 3      6.780000e-05  6.780000e-05  6.780000e-05   0.000068  6.780000e-05
# 4      1.402300e-04  1.402300e-04  1.402300e-04   0.000140  1.402300e-04
# ...             ...           ...           ...        ...           ...
# 12937  1.064900e+01  1.528100e+01  1.970900e+01  21.825001  2.332900e+01
# 12938  1.150000e-06  1.150000e-06  1.150000e-06   0.000001  1.150000e-06
# 12939  2.000000e-08  2.000000e-08  2.000000e-08   0.010000  2.000000e-08
# 12940  0.000000e+00  0.000000e+00  0.000000e+00   0.000000  0.000000e+00
# 12941  1.291000e-05  1.291000e-05  4.000013e+00  10.384013  1.942801e+01
#
#          2024-07  ...       2026-04       2026-05       2026-06       2026-07  \
# 0      23.215012  ...  3.069650e+01  2.879885e+01  3.129597e+01  2.524406e+01
# 1      65.320047  ...  6.334447e+01  6.160682e+01  6.292587e+01  5.922958e+01
# 2       0.316001  ...  6.641399e-01  8.664406e-01  1.310515e+00  1.196393e+00
# 3       0.000068  ...  6.780000e-05  6.780000e-05  6.780000e-05  6.780000e-05
# 4       0.000140  ...  1.402300e-04  1.402300e-04  1.402300e-04  1.402300e-04
# ...          ...  ...           ...           ...           ...           ...
# 12937  25.526001  ...  1.050000e-06  1.050000e-06  1.050000e-06  1.050000e-06
# 12938   0.000001  ...  1.150000e-06  1.150000e-06  1.150000e-06  1.150000e-06
# 12939   0.018000  ...  2.000000e-08  2.000000e-08  2.000000e-08  2.000000e-08
# 12940   0.000000  ...  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 12941  17.798013  ...  1.501433e+00  7.656156e+00  1.959050e+01  1.510924e+01
#
#             2026-08       2026-09       2026-10       2026-11       2026-12  \
# 0      3.907461e+01  3.198991e+01  3.275574e+01  3.359623e+01  3.349689e+01
# 1      5.808427e+01  5.758117e+01  6.043905e+01  6.282416e+01  5.911095e+01
# 2      8.280460e-01  6.345409e-01  9.671610e-01  1.123312e+00  9.359308e-01
# 3      6.780000e-05  6.780000e-05  6.780000e-05  6.780000e-05  6.780000e-05
# 4      1.402300e-04  1.402300e-04  1.402300e-04  1.402300e-04  1.402300e-04
# ...             ...           ...           ...           ...           ...
# 12937  1.050000e-06  1.050000e-06  1.050000e-06  1.050000e-06  1.050000e-06
# 12938  1.150000e-06  1.150000e-06  1.150000e-06  1.150000e-06  1.150000e-06
# 12939  2.000000e-08  2.000000e-08  2.000000e-08  2.000000e-08  2.000000e-08
# 12940  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 12941  1.171929e+01  3.195908e+00  7.992366e-01  1.954560e+00  4.602579e-02
#
#        CodEs
# 0      10004
# 1      10004
# 2      10004
# 3      10004
# 4      10004
# ...      ...
# 12937  60999
# 12938  60999
# 12939  60999
# 12940  60999
# 12941  60999
#
# [12942 rows x 40 columns]

# %%
base_poa.groupby(by=['Producto'])['2025-01'].sum()
# Out:
# Producto
# DSL      318606.569421
# GAS      264571.388876
# GASES       941.939582
# KER         225.776297
# Name: 2025-01, dtype: float64

# %%
# Generación archivos
output_dir = base_dir / "Carga Inicial" / "Archivos por Zona Respaldo"
dir_molde = base_dir / "Carga Inicial" / "(Paso-1) ArchivosSinProyMacro" / "Formato POA JZ - Concesionarios.xlsx"


# --- Crear carpetas por zona ---output_dir = base_dir / "Carga Inicial" / "Archivos por Zona Respaldo"
for zona in zonas:
    directory = Path(dir_base) / str(zona)
    directory.mkdir(parents=True, exist_ok=True)

eds_falla = []

print(maestro_eds)

# --- Iterar maestro_eds agrupado por JZ ---
for cont, (jz, df_jz) in enumerate(maestro_eds.groupby("JZ"), start=1):
    for eds in df_jz["CodEs"]:
        try:
            
            # if(eds not in [40531,40532,40533,40534,60292,60294,60295,60296,60297,60298]):
            #     continue
            
            print(eds)
            
            output_file = output_dir / str(jz) / f"{eds} - Combustibles.xlsx"
            print(output_file)
            
            # if output_file.exists():
            #     print(f"⚠️ Ya existe {output_file}, se omite.")
            #     continue
            
            eds_file(base_poa, base_app_copec, jz, eds, dir_molde, dir_destino=output_file)
            print(f"{cont}: EDS {eds} en JZ {jz}")
        except Exception as e:
            eds_falla.append((eds, jz, str(e)))
            print(f"❌ Fallo EDS {eds} en JZ {jz} -> {e}")
# Out:
#      CodEs   JZ
# 0    10004  220
# 1    10006  220
# 2    10009  220
# 3    10021  221
# 4    10024  220
# ..     ...  ...
# 727  60017  214
# 728  60685  213
# 729  20155  246
# 730  20194  247
# 731  20198  247
#
# [732 rows x 2 columns]
# 60076
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\209\60076 - Combustibles.xlsx
# 1: EDS 60076 en JZ 209
# 60207
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\209\60207 - Combustibles.xlsx
# 1: EDS 60207 en JZ 209
# 60230
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\209\60230 - Combustibles.xlsx
# 1: EDS 60230 en JZ 209
# 60259
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\209\60259 - Combustibles.xlsx
# 1: EDS 60259 en JZ 209
# 60273
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\209\60273 - Combustibles.xlsx
# 1: EDS 60273 en JZ 209
# 60287
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\209\60287 - Combustibles.xlsx
# 1: EDS 60287 en JZ 209
# 60325
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\209\60325 - Combustibles.xlsx
# 1: EDS 60325 en JZ 209
# 60326
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\209\60326 - Combustibles.xlsx
# 1: EDS 60326 en JZ 209
# 60334
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\209\60334 - Combustibles.xlsx
# 1: EDS 60334 en JZ 209
# 60351
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\209\60351 - Combustibles.xlsx
# 1: EDS 60351 en JZ 209
# 60368
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\209\60368 - Combustibles.xlsx
# 1: EDS 60368 en JZ 209
# 60403
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\209\60403 - Combustibles.xlsx
# 1: EDS 60403 en JZ 209
# 60415
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\209\60415 - Combustibles.xlsx
# 1: EDS 60415 en JZ 209
# 60437
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\209\60437 - Combustibles.xlsx
# 1: EDS 60437 en JZ 209
# 60441
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\209\60441 - Combustibles.xlsx
# 1: EDS 60441 en JZ 209
# 60447
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\209\60447 - Combustibles.xlsx
# 1: EDS 60447 en JZ 209
# 60758
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\209\60758 - Combustibles.xlsx
# 1: EDS 60758 en JZ 209
# 60781
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\209\60781 - Combustibles.xlsx
# 1: EDS 60781 en JZ 209
# 60855
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\209\60855 - Combustibles.xlsx
# 1: EDS 60855 en JZ 209
# 60297
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\209\60297 - Combustibles.xlsx
# 1: EDS 60297 en JZ 209
# 60321
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\209\60321 - Combustibles.xlsx
# 1: EDS 60321 en JZ 209
# 60014
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\210\60014 - Combustibles.xlsx
# 2: EDS 60014 en JZ 210
# 60045
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\210\60045 - Combustibles.xlsx
# 2: EDS 60045 en JZ 210
# 60046
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\210\60046 - Combustibles.xlsx
# 2: EDS 60046 en JZ 210
# 60047
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\210\60047 - Combustibles.xlsx
# 2: EDS 60047 en JZ 210
# 60055
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\210\60055 - Combustibles.xlsx
# 2: EDS 60055 en JZ 210
# 60064
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\210\60064 - Combustibles.xlsx
# 2: EDS 60064 en JZ 210
# 60098
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\210\60098 - Combustibles.xlsx
# 2: EDS 60098 en JZ 210
# 60107
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\210\60107 - Combustibles.xlsx
# 2: EDS 60107 en JZ 210
# 60132
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\210\60132 - Combustibles.xlsx
# 2: EDS 60132 en JZ 210
# 60139
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\210\60139 - Combustibles.xlsx
# 2: EDS 60139 en JZ 210
# 60232
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\210\60232 - Combustibles.xlsx
# 2: EDS 60232 en JZ 210
# 60241
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\210\60241 - Combustibles.xlsx
# 2: EDS 60241 en JZ 210
# 60249
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\210\60249 - Combustibles.xlsx
# 2: EDS 60249 en JZ 210
# 60253
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\210\60253 - Combustibles.xlsx
# 2: EDS 60253 en JZ 210
# 60268
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\210\60268 - Combustibles.xlsx
# 2: EDS 60268 en JZ 210
# 60305
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\210\60305 - Combustibles.xlsx
# 2: EDS 60305 en JZ 210
# 60395
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\210\60395 - Combustibles.xlsx
# 2: EDS 60395 en JZ 210
# 60405
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\210\60405 - Combustibles.xlsx
# 2: EDS 60405 en JZ 210
# 60412
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\210\60412 - Combustibles.xlsx
# 2: EDS 60412 en JZ 210
# 60540
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\210\60540 - Combustibles.xlsx
# 2: EDS 60540 en JZ 210
# 60640
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\210\60640 - Combustibles.xlsx
# 2: EDS 60640 en JZ 210
# 60691
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\210\60691 - Combustibles.xlsx
# 2: EDS 60691 en JZ 210
# 60711
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\210\60711 - Combustibles.xlsx
# 2: EDS 60711 en JZ 210
# 60753
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\210\60753 - Combustibles.xlsx
# 2: EDS 60753 en JZ 210
# 60999
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\210\60999 - Combustibles.xlsx
# 2: EDS 60999 en JZ 210
# 60300
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\210\60300 - Combustibles.xlsx
# 2: EDS 60300 en JZ 210
# 60006
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\211\60006 - Combustibles.xlsx
# 3: EDS 60006 en JZ 211
# 60012
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\211\60012 - Combustibles.xlsx
# 3: EDS 60012 en JZ 211
# 60088
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\211\60088 - Combustibles.xlsx
# 3: EDS 60088 en JZ 211
# 60113
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\211\60113 - Combustibles.xlsx
# 3: EDS 60113 en JZ 211
# 60120
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\211\60120 - Combustibles.xlsx
# 3: EDS 60120 en JZ 211
# 60128
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\211\60128 - Combustibles.xlsx
# 3: EDS 60128 en JZ 211
# 60140
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\211\60140 - Combustibles.xlsx
# 3: EDS 60140 en JZ 211
# 60142
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\211\60142 - Combustibles.xlsx
# 3: EDS 60142 en JZ 211
# 60145
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\211\60145 - Combustibles.xlsx
# 3: EDS 60145 en JZ 211
# 60158
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\211\60158 - Combustibles.xlsx
# 3: EDS 60158 en JZ 211
# 60265
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\211\60265 - Combustibles.xlsx
# 3: EDS 60265 en JZ 211
# 60312
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\211\60312 - Combustibles.xlsx
# 3: EDS 60312 en JZ 211
# 60380
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\211\60380 - Combustibles.xlsx
# 3: EDS 60380 en JZ 211
# 60386
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\211\60386 - Combustibles.xlsx
# 3: EDS 60386 en JZ 211
# 60411
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\211\60411 - Combustibles.xlsx
# 3: EDS 60411 en JZ 211
# 60417
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\211\60417 - Combustibles.xlsx
# 3: EDS 60417 en JZ 211
# 60430
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\211\60430 - Combustibles.xlsx
# 3: EDS 60430 en JZ 211
# 60455
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\211\60455 - Combustibles.xlsx
# 3: EDS 60455 en JZ 211
# 60503
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\211\60503 - Combustibles.xlsx
# 3: EDS 60503 en JZ 211
# 60745
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\211\60745 - Combustibles.xlsx
# 3: EDS 60745 en JZ 211
# 60280
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\211\60280 - Combustibles.xlsx
# 3: EDS 60280 en JZ 211
# 60291
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\211\60291 - Combustibles.xlsx
# 3: EDS 60291 en JZ 211
# 60011
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\212\60011 - Combustibles.xlsx
# 4: EDS 60011 en JZ 212
# 60035
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\212\60035 - Combustibles.xlsx
# 4: EDS 60035 en JZ 212
# 60040
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\212\60040 - Combustibles.xlsx
# 4: EDS 60040 en JZ 212
# 60069
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\212\60069 - Combustibles.xlsx
# 4: EDS 60069 en JZ 212
# 60075
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\212\60075 - Combustibles.xlsx
# 4: EDS 60075 en JZ 212
# 60096
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\212\60096 - Combustibles.xlsx
# 4: EDS 60096 en JZ 212
# 60101
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\212\60101 - Combustibles.xlsx
# 4: EDS 60101 en JZ 212
# 60102
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\212\60102 - Combustibles.xlsx
# 4: EDS 60102 en JZ 212
# 60134
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\212\60134 - Combustibles.xlsx
# 4: EDS 60134 en JZ 212
# 60135
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\212\60135 - Combustibles.xlsx
# 4: EDS 60135 en JZ 212
# 60137
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\212\60137 - Combustibles.xlsx
# 4: EDS 60137 en JZ 212
# 60195
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\212\60195 - Combustibles.xlsx
# 4: EDS 60195 en JZ 212
# 60242
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\212\60242 - Combustibles.xlsx
# 4: EDS 60242 en JZ 212
# 60267
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\212\60267 - Combustibles.xlsx
# 4: EDS 60267 en JZ 212
# 60358
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\212\60358 - Combustibles.xlsx
# 4: EDS 60358 en JZ 212
# 60370
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\212\60370 - Combustibles.xlsx
# 4: EDS 60370 en JZ 212
# 60388
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\212\60388 - Combustibles.xlsx
# 4: EDS 60388 en JZ 212
# 60392
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\212\60392 - Combustibles.xlsx
# 4: EDS 60392 en JZ 212
# 60401
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\212\60401 - Combustibles.xlsx
# 4: EDS 60401 en JZ 212
# 60407
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\212\60407 - Combustibles.xlsx
# 4: EDS 60407 en JZ 212
# 60413
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\212\60413 - Combustibles.xlsx
# 4: EDS 60413 en JZ 212
# 60419
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\212\60419 - Combustibles.xlsx
# 4: EDS 60419 en JZ 212
# 60423
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\212\60423 - Combustibles.xlsx
# 4: EDS 60423 en JZ 212
# 60987
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\212\60987 - Combustibles.xlsx
# 4: EDS 60987 en JZ 212
# 60294
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\212\60294 - Combustibles.xlsx
# 4: EDS 60294 en JZ 212
# 60013
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\213\60013 - Combustibles.xlsx
# 5: EDS 60013 en JZ 213
# 60209
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\213\60209 - Combustibles.xlsx
# 5: EDS 60209 en JZ 213
# 60210
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\213\60210 - Combustibles.xlsx
# 5: EDS 60210 en JZ 213
# 60251
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\213\60251 - Combustibles.xlsx
# 5: EDS 60251 en JZ 213
# 60261
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\213\60261 - Combustibles.xlsx
# 5: EDS 60261 en JZ 213
# 60263
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\213\60263 - Combustibles.xlsx
# 5: EDS 60263 en JZ 213
# 60332
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\213\60332 - Combustibles.xlsx
# 5: EDS 60332 en JZ 213
# 60333
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\213\60333 - Combustibles.xlsx
# 5: EDS 60333 en JZ 213
# 60335
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\213\60335 - Combustibles.xlsx
# 5: EDS 60335 en JZ 213
# 60336
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\213\60336 - Combustibles.xlsx
# 5: EDS 60336 en JZ 213
# 60338
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\213\60338 - Combustibles.xlsx
# 5: EDS 60338 en JZ 213
# 60339
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\213\60339 - Combustibles.xlsx
# 5: EDS 60339 en JZ 213
# 60341
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\213\60341 - Combustibles.xlsx
# 5: EDS 60341 en JZ 213
# 60359
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\213\60359 - Combustibles.xlsx
# 5: EDS 60359 en JZ 213
# 60409
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\213\60409 - Combustibles.xlsx
# 5: EDS 60409 en JZ 213
# 60428
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\213\60428 - Combustibles.xlsx
# 5: EDS 60428 en JZ 213
# 60434
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\213\60434 - Combustibles.xlsx
# 5: EDS 60434 en JZ 213
# 60438
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\213\60438 - Combustibles.xlsx
# 5: EDS 60438 en JZ 213
# 60439
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\213\60439 - Combustibles.xlsx
# 5: EDS 60439 en JZ 213
# 60444
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\213\60444 - Combustibles.xlsx
# 5: EDS 60444 en JZ 213
# 60445
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\213\60445 - Combustibles.xlsx
# 5: EDS 60445 en JZ 213
# 60490
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\213\60490 - Combustibles.xlsx
# 5: EDS 60490 en JZ 213
# 60782
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\213\60782 - Combustibles.xlsx
# 5: EDS 60782 en JZ 213
# 60838
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\213\60838 - Combustibles.xlsx
# 5: EDS 60838 en JZ 213
# 60685
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\213\60685 - Combustibles.xlsx
# 5: EDS 60685 en JZ 213
# 60298
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\213\60298 - Combustibles.xlsx
# 5: EDS 60298 en JZ 213
# 60295
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\213\60295 - Combustibles.xlsx
# 5: EDS 60295 en JZ 213
# 60296
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\213\60296 - Combustibles.xlsx
# 5: EDS 60296 en JZ 213
# 60685
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\213\60685 - Combustibles.xlsx
# 5: EDS 60685 en JZ 213
# 60044
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\214\60044 - Combustibles.xlsx
# 6: EDS 60044 en JZ 214
# 60048
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\214\60048 - Combustibles.xlsx
# 6: EDS 60048 en JZ 214
# 60093
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\214\60093 - Combustibles.xlsx
# 6: EDS 60093 en JZ 214
# 60097
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\214\60097 - Combustibles.xlsx
# 6: EDS 60097 en JZ 214
# 60106
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\214\60106 - Combustibles.xlsx
# 6: EDS 60106 en JZ 214
# 60196
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\214\60196 - Combustibles.xlsx
# 6: EDS 60196 en JZ 214
# 60225
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\214\60225 - Combustibles.xlsx
# 6: EDS 60225 en JZ 214
# 60236
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\214\60236 - Combustibles.xlsx
# 6: EDS 60236 en JZ 214
# 60266
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\214\60266 - Combustibles.xlsx
# 6: EDS 60266 en JZ 214
# 60282
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\214\60282 - Combustibles.xlsx
# 6: EDS 60282 en JZ 214
# 60284
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\214\60284 - Combustibles.xlsx
# 6: EDS 60284 en JZ 214
# 60314
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\214\60314 - Combustibles.xlsx
# 6: EDS 60314 en JZ 214
# 60317
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\214\60317 - Combustibles.xlsx
# 6: EDS 60317 en JZ 214
# 60320
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\214\60320 - Combustibles.xlsx
# 6: EDS 60320 en JZ 214
# 60348
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\214\60348 - Combustibles.xlsx
# 6: EDS 60348 en JZ 214
# 60350
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\214\60350 - Combustibles.xlsx
# 6: EDS 60350 en JZ 214
# 60374
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\214\60374 - Combustibles.xlsx
# 6: EDS 60374 en JZ 214
# 60394
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\214\60394 - Combustibles.xlsx
# 6: EDS 60394 en JZ 214
# 60418
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\214\60418 - Combustibles.xlsx
# 6: EDS 60418 en JZ 214
# 60470
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\214\60470 - Combustibles.xlsx
# 6: EDS 60470 en JZ 214
# 60471
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\214\60471 - Combustibles.xlsx
# 6: EDS 60471 en JZ 214
# 60561
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\214\60561 - Combustibles.xlsx
# 6: EDS 60561 en JZ 214
# 60827
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\214\60827 - Combustibles.xlsx
# 6: EDS 60827 en JZ 214
# 60016
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\214\60016 - Combustibles.xlsx
# 6: EDS 60016 en JZ 214
# 60017
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\214\60017 - Combustibles.xlsx
# 6: EDS 60017 en JZ 214
# 60293
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\214\60293 - Combustibles.xlsx
# 6: EDS 60293 en JZ 214
# 60016
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\214\60016 - Combustibles.xlsx
# 6: EDS 60016 en JZ 214
# 60017
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\214\60017 - Combustibles.xlsx
# 6: EDS 60017 en JZ 214
# 60021
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\215\60021 - Combustibles.xlsx
# 7: EDS 60021 en JZ 215
# 60042
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\215\60042 - Combustibles.xlsx
# 7: EDS 60042 en JZ 215
# 60054
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\215\60054 - Combustibles.xlsx
# 7: EDS 60054 en JZ 215
# 60077
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\215\60077 - Combustibles.xlsx
# 7: EDS 60077 en JZ 215
# 60090
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\215\60090 - Combustibles.xlsx
# 7: EDS 60090 en JZ 215
# 60115
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\215\60115 - Combustibles.xlsx
# 7: EDS 60115 en JZ 215
# 60123
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\215\60123 - Combustibles.xlsx
# 7: EDS 60123 en JZ 215
# 60141
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\215\60141 - Combustibles.xlsx
# 7: EDS 60141 en JZ 215
# 60143
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\215\60143 - Combustibles.xlsx
# 7: EDS 60143 en JZ 215
# 60224
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\215\60224 - Combustibles.xlsx
# 7: EDS 60224 en JZ 215
# 60227
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\215\60227 - Combustibles.xlsx
# 7: EDS 60227 en JZ 215
# 60235
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\215\60235 - Combustibles.xlsx
# 7: EDS 60235 en JZ 215
# 60237
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\215\60237 - Combustibles.xlsx
# 7: EDS 60237 en JZ 215
# 60243
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\215\60243 - Combustibles.xlsx
# 7: EDS 60243 en JZ 215
# 60246
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\215\60246 - Combustibles.xlsx
# 7: EDS 60246 en JZ 215
# 60355
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\215\60355 - Combustibles.xlsx
# 7: EDS 60355 en JZ 215
# 60369
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\215\60369 - Combustibles.xlsx
# 7: EDS 60369 en JZ 215
# 60384
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\215\60384 - Combustibles.xlsx
# 7: EDS 60384 en JZ 215
# 60416
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\215\60416 - Combustibles.xlsx
# 7: EDS 60416 en JZ 215
# 60424
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\215\60424 - Combustibles.xlsx
# 7: EDS 60424 en JZ 215
# 60524
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\215\60524 - Combustibles.xlsx
# 7: EDS 60524 en JZ 215
# 60618
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\215\60618 - Combustibles.xlsx
# 7: EDS 60618 en JZ 215
# 60664
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\215\60664 - Combustibles.xlsx
# 7: EDS 60664 en JZ 215
# 60028
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\216\60028 - Combustibles.xlsx
# 8: EDS 60028 en JZ 216
# 60036
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\216\60036 - Combustibles.xlsx
# 8: EDS 60036 en JZ 216
# 60037
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\216\60037 - Combustibles.xlsx
# 8: EDS 60037 en JZ 216
# 60050
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\216\60050 - Combustibles.xlsx
# 8: EDS 60050 en JZ 216
# 60057
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\216\60057 - Combustibles.xlsx
# 8: EDS 60057 en JZ 216
# 60073
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\216\60073 - Combustibles.xlsx
# 8: EDS 60073 en JZ 216
# 60079
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\216\60079 - Combustibles.xlsx
# 8: EDS 60079 en JZ 216
# 60085
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\216\60085 - Combustibles.xlsx
# 8: EDS 60085 en JZ 216
# 60092
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\216\60092 - Combustibles.xlsx
# 8: EDS 60092 en JZ 216
# 60108
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\216\60108 - Combustibles.xlsx
# 8: EDS 60108 en JZ 216
# 60110
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\216\60110 - Combustibles.xlsx
# 8: EDS 60110 en JZ 216
# 60133
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\216\60133 - Combustibles.xlsx
# 8: EDS 60133 en JZ 216
# 60286
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\216\60286 - Combustibles.xlsx
# 8: EDS 60286 en JZ 216
# 60289
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\216\60289 - Combustibles.xlsx
# 8: EDS 60289 en JZ 216
# 60375
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\216\60375 - Combustibles.xlsx
# 8: EDS 60375 en JZ 216
# 60387
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\216\60387 - Combustibles.xlsx
# 8: EDS 60387 en JZ 216
# 60425
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\216\60425 - Combustibles.xlsx
# 8: EDS 60425 en JZ 216
# 60433
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\216\60433 - Combustibles.xlsx
# 8: EDS 60433 en JZ 216
# 60450
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\216\60450 - Combustibles.xlsx
# 8: EDS 60450 en JZ 216
# 60512
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\216\60512 - Combustibles.xlsx
# 8: EDS 60512 en JZ 216
# 60635
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\216\60635 - Combustibles.xlsx
# 8: EDS 60635 en JZ 216
# 60701
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\216\60701 - Combustibles.xlsx
# 8: EDS 60701 en JZ 216
# 60712
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\216\60712 - Combustibles.xlsx
# 8: EDS 60712 en JZ 216
# 60741
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\216\60741 - Combustibles.xlsx
# 8: EDS 60741 en JZ 216
# 60742
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\216\60742 - Combustibles.xlsx
# 8: EDS 60742 en JZ 216
# 60773
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\216\60773 - Combustibles.xlsx
# 8: EDS 60773 en JZ 216
# 60814
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\216\60814 - Combustibles.xlsx
# 8: EDS 60814 en JZ 216
# 60001
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\217\60001 - Combustibles.xlsx
# 9: EDS 60001 en JZ 217
# 60004
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\217\60004 - Combustibles.xlsx
# 9: EDS 60004 en JZ 217
# 60008
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\217\60008 - Combustibles.xlsx
# 9: EDS 60008 en JZ 217
# 60015
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\217\60015 - Combustibles.xlsx
# 9: EDS 60015 en JZ 217
# 60041
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\217\60041 - Combustibles.xlsx
# 9: EDS 60041 en JZ 217
# 60068
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\217\60068 - Combustibles.xlsx
# 9: EDS 60068 en JZ 217
# 60070
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\217\60070 - Combustibles.xlsx
# 9: EDS 60070 en JZ 217
# 60072
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\217\60072 - Combustibles.xlsx
# 9: EDS 60072 en JZ 217
# 60078
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\217\60078 - Combustibles.xlsx
# 9: EDS 60078 en JZ 217
# 60086
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\217\60086 - Combustibles.xlsx
# 9: EDS 60086 en JZ 217
# 60126
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\217\60126 - Combustibles.xlsx
# 9: EDS 60126 en JZ 217
# 60166
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\217\60166 - Combustibles.xlsx
# 9: EDS 60166 en JZ 217
# 60192
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\217\60192 - Combustibles.xlsx
# 9: EDS 60192 en JZ 217
# 60197
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\217\60197 - Combustibles.xlsx
# 9: EDS 60197 en JZ 217
# 60198
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\217\60198 - Combustibles.xlsx
# 9: EDS 60198 en JZ 217
# 60226
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\217\60226 - Combustibles.xlsx
# 9: EDS 60226 en JZ 217
# 60279
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\217\60279 - Combustibles.xlsx
# 9: EDS 60279 en JZ 217
# 60288
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\217\60288 - Combustibles.xlsx
# 9: EDS 60288 en JZ 217
# 60308
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\217\60308 - Combustibles.xlsx
# 9: EDS 60308 en JZ 217
# 60371
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\217\60371 - Combustibles.xlsx
# 9: EDS 60371 en JZ 217
# 60406
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\217\60406 - Combustibles.xlsx
# 9: EDS 60406 en JZ 217
# 60426
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\217\60426 - Combustibles.xlsx
# 9: EDS 60426 en JZ 217
# 60601
# ...
# 27: EDS 20201 en JZ 247
# 20219
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\247\20219 - Combustibles.xlsx
# 27: EDS 20219 en JZ 247
# 20222
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\247\20222 - Combustibles.xlsx
# 27: EDS 20222 en JZ 247
# 20230
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\247\20230 - Combustibles.xlsx
# 27: EDS 20230 en JZ 247
# 20232
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\247\20232 - Combustibles.xlsx
# 27: EDS 20232 en JZ 247
# 20235
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\247\20235 - Combustibles.xlsx
# 27: EDS 20235 en JZ 247
# 20239
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\247\20239 - Combustibles.xlsx
# 27: EDS 20239 en JZ 247
# 20327
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\247\20327 - Combustibles.xlsx
# 27: EDS 20327 en JZ 247
# 20375
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\247\20375 - Combustibles.xlsx
# 27: EDS 20375 en JZ 247
# 20442
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\247\20442 - Combustibles.xlsx
# 27: EDS 20442 en JZ 247
# 20455
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\247\20455 - Combustibles.xlsx
# 27: EDS 20455 en JZ 247
# 20467
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\247\20467 - Combustibles.xlsx
# 27: EDS 20467 en JZ 247
# 20523
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\247\20523 - Combustibles.xlsx
# 27: EDS 20523 en JZ 247
# 20567
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\247\20567 - Combustibles.xlsx
# 27: EDS 20567 en JZ 247
# 20605
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\247\20605 - Combustibles.xlsx
# 27: EDS 20605 en JZ 247
# 20607
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\247\20607 - Combustibles.xlsx
# 27: EDS 20607 en JZ 247
# 20906
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\247\20906 - Combustibles.xlsx
# 27: EDS 20906 en JZ 247
# 20216
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\247\20216 - Combustibles.xlsx
# 27: EDS 20216 en JZ 247
# 20587
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\247\20587 - Combustibles.xlsx
# 27: EDS 20587 en JZ 247
# 20216
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\247\20216 - Combustibles.xlsx
# 27: EDS 20216 en JZ 247
# 20194
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\247\20194 - Combustibles.xlsx
# 27: EDS 20194 en JZ 247
# 20198
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\247\20198 - Combustibles.xlsx
# 27: EDS 20198 en JZ 247
# 20011
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\248\20011 - Combustibles.xlsx
# 28: EDS 20011 en JZ 248
# 20043
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\248\20043 - Combustibles.xlsx
# 28: EDS 20043 en JZ 248
# 20046
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\248\20046 - Combustibles.xlsx
# 28: EDS 20046 en JZ 248
# 20080
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\248\20080 - Combustibles.xlsx
# 28: EDS 20080 en JZ 248
# 20146
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\248\20146 - Combustibles.xlsx
# 28: EDS 20146 en JZ 248
# 20290
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\248\20290 - Combustibles.xlsx
# 28: EDS 20290 en JZ 248
# 20373
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\248\20373 - Combustibles.xlsx
# 28: EDS 20373 en JZ 248
# 20389
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\248\20389 - Combustibles.xlsx
# 28: EDS 20389 en JZ 248
# 20407
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\248\20407 - Combustibles.xlsx
# 28: EDS 20407 en JZ 248
# 20435
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\248\20435 - Combustibles.xlsx
# 28: EDS 20435 en JZ 248
# 20456
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\248\20456 - Combustibles.xlsx
# 28: EDS 20456 en JZ 248
# 20468
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\248\20468 - Combustibles.xlsx
# 28: EDS 20468 en JZ 248
# 20505
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\248\20505 - Combustibles.xlsx
# 28: EDS 20505 en JZ 248
# 20509
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\248\20509 - Combustibles.xlsx
# 28: EDS 20509 en JZ 248
# 20517
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\248\20517 - Combustibles.xlsx
# 28: EDS 20517 en JZ 248
# 20561
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\248\20561 - Combustibles.xlsx
# 28: EDS 20561 en JZ 248
# 20592
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\248\20592 - Combustibles.xlsx
# 28: EDS 20592 en JZ 248
# 20722
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\248\20722 - Combustibles.xlsx
# 28: EDS 20722 en JZ 248
# 20794
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\248\20794 - Combustibles.xlsx
# 28: EDS 20794 en JZ 248
# 20864
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\248\20864 - Combustibles.xlsx
# 28: EDS 20864 en JZ 248
# 20889
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\248\20889 - Combustibles.xlsx
# 28: EDS 20889 en JZ 248
# 20900
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\248\20900 - Combustibles.xlsx
# 28: EDS 20900 en JZ 248
# 20933
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\248\20933 - Combustibles.xlsx
# 28: EDS 20933 en JZ 248
# 20939
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\248\20939 - Combustibles.xlsx
# 28: EDS 20939 en JZ 248
# 20944
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\248\20944 - Combustibles.xlsx
# 28: EDS 20944 en JZ 248
# 20950
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\248\20950 - Combustibles.xlsx
# 28: EDS 20950 en JZ 248
# 20589
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\248\20589 - Combustibles.xlsx
# 28: EDS 20589 en JZ 248
# 20098
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\249\20098 - Combustibles.xlsx
# 29: EDS 20098 en JZ 249
# 20099
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\249\20099 - Combustibles.xlsx
# 29: EDS 20099 en JZ 249
# 20100
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\249\20100 - Combustibles.xlsx
# 29: EDS 20100 en JZ 249
# 20120
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\249\20120 - Combustibles.xlsx
# 29: EDS 20120 en JZ 249
# 20188
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\249\20188 - Combustibles.xlsx
# 29: EDS 20188 en JZ 249
# 20202
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\249\20202 - Combustibles.xlsx
# 29: EDS 20202 en JZ 249
# 20204
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\249\20204 - Combustibles.xlsx
# 29: EDS 20204 en JZ 249
# 20207
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\249\20207 - Combustibles.xlsx
# 29: EDS 20207 en JZ 249
# 20215
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\249\20215 - Combustibles.xlsx
# 29: EDS 20215 en JZ 249
# 20226
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\249\20226 - Combustibles.xlsx
# 29: EDS 20226 en JZ 249
# 20316
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\249\20316 - Combustibles.xlsx
# 29: EDS 20316 en JZ 249
# 20424
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\249\20424 - Combustibles.xlsx
# 29: EDS 20424 en JZ 249
# 20425
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\249\20425 - Combustibles.xlsx
# 29: EDS 20425 en JZ 249
# 20471
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\249\20471 - Combustibles.xlsx
# 29: EDS 20471 en JZ 249
# 20507
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\249\20507 - Combustibles.xlsx
# 29: EDS 20507 en JZ 249
# 20537
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\249\20537 - Combustibles.xlsx
# 29: EDS 20537 en JZ 249
# 20574
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\249\20574 - Combustibles.xlsx
# 29: EDS 20574 en JZ 249
# 20576
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\249\20576 - Combustibles.xlsx
# 29: EDS 20576 en JZ 249
# 20581
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\249\20581 - Combustibles.xlsx
# 29: EDS 20581 en JZ 249
# 20582
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\249\20582 - Combustibles.xlsx
# 29: EDS 20582 en JZ 249
# 20716
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\249\20716 - Combustibles.xlsx
# 29: EDS 20716 en JZ 249
# 20806
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\249\20806 - Combustibles.xlsx
# 29: EDS 20806 en JZ 249
# 20825
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\249\20825 - Combustibles.xlsx
# 29: EDS 20825 en JZ 249
# 20830
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\249\20830 - Combustibles.xlsx
# 29: EDS 20830 en JZ 249
# 20905
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\249\20905 - Combustibles.xlsx
# 29: EDS 20905 en JZ 249
# 20614
# G:\Unidades compartidas\2_Planificación Comercial - EDS\4. POA\POA Gestión\POA 2026\POA Comercial - Carga Inicial\Carga Inicial\Archivos por Zona Respaldo\249\20614 - Combustibles.xlsx
# 29: EDS 20614 en JZ 249

# %%
eds_falla

# %%
eds_file(base_poa, base_app_copec, 214, 60293)

# %% [markdown]
# ## Archivos Finales en base a Carga Inicial

# %%
dir_maestro_eds = r"G:\Unidades compartidas\2_Planificación Comercial - Combustibles\4. POA\POA Gestión\POA 2024\Carga Inicial\Maestro EDS.xlsx"

maestro_eds = pd.read_excel(dir_maestro_eds, usecols=[0, 5], sheet_name='Consolidado')
estacionales = pd.read_excel(dir_maestro_eds, usecols=[0, 12], names=['CodEs', 'JZ'], sheet_name='Estacionales')
maestro_eds = maestro_eds.append(estacionales)


dir_archivo_base_final = r"G:\Unidades compartidas\2_Planificación Comercial - Combustibles\4. POA\POA Gestión\POA 2024\Carga Inicial\Carga Inicial V4 EDS.xlsx"

base_poa_final = pd.read_excel(dir_archivo_base_final, skiprows=1, sheet_name="Carga Inicial - Volumen", usecols="A:AN")

# %%
details_form_com = [['DSL', 'Cupón Electrónico'], ['DSL', 'FF.AA'], ['DSL', 'Muevo Empresa'], ['DSL', 'TAE'], ['DSL', 'TCT'], ['DSL', 'Venta Propia - Camión de Reparto'],
['DSL', 'Venta Propia - Isla'], ['GAS', 'Cupón Electrónico'], ['GAS', 'FF.AA'], ['GAS', 'G93 - VP'], ['GAS', 'G95 - VP'], ['GAS', 'G97 - VP'], ['GAS', 'Muevo Empresa'],
['GASES', 'GLP'], ['GASES', 'GNC'], ['KER', 'Muevo Empresa'], ['KER', 'Venta Propia - Camión de Reparto'], ['KER', 'Venta Propia - Isla']]

cols_proy = ['2022-1',	'2022-2',	'2022-3',	'2022-4',	'2022-5',	'2022-6',	'2022-7',	'2022-8',	'2022-9',	'2022-10',	'2022-11',	'2022-12',	'2023-1',	'2023-2',	'2023-3',	'2023-4',	'2023-5',	'2023-6',	'2023-7',	'2023-8',	'2023-9',	'2023-10',	'2023-11',	'2023-12',	'2024-1',	'2024-2',	'2024-3',	'2024-4',	'2024-5',	'2024-6',	'2024-7',	'2024-8',	'2024-9',	'2024-10',	'2024-11',	'2024-12']
for option in details_form_com:
   base_poa_final.loc[(base_poa_final.Producto == option[0]) & (base_poa_final['Forma Comercialización'] == option[1]), (cols_proy)] = base_poa_final.loc[(base_poa_final.Producto == option[0]) & (base_poa_final['Forma Comercialización'] == option[1]), (cols_proy)].add(sum_prop(option[0], option[1]))


base_poa_final

# %%
#eds_file_final(base_poa_final, 213, 60444)

# %%
cont = 1
for jz in maestro_eds.JZ.unique():
    for eds in maestro_eds[maestro_eds.JZ == jz].CodEs:
        eds_file_final(base_poa_final, jz, eds)
        print(cont, eds, jz)
        cont += 1
